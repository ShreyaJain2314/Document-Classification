# %%
import pandas as pd
import numpy as np
import os
train_data= pd.read_csv("trainingdata.csv",encoding="unicode escape")
#test_data=pd.read_csv("testdata.csv",encoding="unicode escape")

# %%
train_data
# Out:
#                 Tag                                               Text
# 0    bank statement  page 10f5 03/02/2022 dc 1090001004230 gs anyco...
# 1           invoice  anycompany retail services date mar26,2018_ ll...
# 2           invoice  anycompany llc 7688 florencio causeway millsbu...
# 3    bank statement  page 1of5 03/02/2022 dc 1090001004290, ge anyc...
# 4    bank statement  page 10f5 03/02/2022 dc 1090001004290 . 999999...
# ..              ...                                                ...
# 342         invoice  anycompany dealers date jun 20, 2018 85899 her...
# 343  business proof  nagaswara hhusie publishing surat keterangan k...
# 344         invoice  anycompany hardware date jan 20, 2020 s s invo...
# 345   address proof  affidavit of residence . application implement...
# 346  bank statement  page 10f5 03/02/2022 dc 1090001004290 99999999...
#
# [347 rows x 2 columns]

# %%
from sklearn.preprocessing import OneHotEncoder as OHE

y_encoder= OHE().fit(np.array(train_data.Tag).reshape(-1,1))

# %%
ytr_encoded= y_encoder.transform(np.array(train_data.Tag).reshape(-1,1)).toarray()
#yts_encoded= y_encoder.transform(np.array(tags).reshape(-1,1)).toarray()

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')
train_data["tokenized"]= train_data.Text.map(word_tokenize)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SJain\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.corpus import stopwords
from string import punctuation
nltk.download('stopwords')
def remove_stop(strings, stop_list):
    classed= [s for s in strings if s not in stop_list]
    return classed

stop= stopwords.words("english")
stop_punc= list(set(punctuation))+ stop

train_data["selected"]= train_data.tokenized.map(lambda df: remove_stop(df, stop_punc))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SJain\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

def normalize(text):
    return " ".join(text)

stemmer= PorterStemmer()

train_data["stemmed"]= train_data.selected.map(lambda xs: [stemmer.stem(x) for x in xs])
train_data["normalized"]= train_data.stemmed.apply(normalize)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer= Tokenizer(num_words= 10000)
tokenizer.fit_on_texts(train_data.normalized)

tokenized_train= tokenizer.texts_to_sequences(train_data.normalized)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

train_padded= pad_sequences(tokenized_train, maxlen= 20, padding= "pre")

# %%
def transform_x(data, tokenizer):
    output_shape= [data.shape[0],
                  data.shape[1],
                  tokenizer.word_index.keys().__len__()]
    results= np.zeros(output_shape)
    
    for i in range(data.shape[0]):
        for ii in range(data.shape[1]):
            results[i, ii, data[i,ii]-1]= 1
    return results

xtr_transformed= transform_x(train_padded, tokenizer)

# %%
from tensorflow.keras.layers import Dense, LSTM, BatchNormalization, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy as CC
from tensorflow.keras.activations import relu, softmax
from tensorflow.keras.initializers import he_uniform, glorot_uniform
from tensorflow.keras.metrics import AUC
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2
import tensorflow as tf

#@tf.function
class LSTMModel(object):
    
    #@tf.function
    def build_model(self, input_dim, output_shape, steps, dropout_rate, kernel_regularizer, bias_regularizer):
        input_layer= Input(shape= (steps, input_dim))
        
        #make lstm_layer
        lstm= LSTM(units= steps)(input_layer)
        dense_1= Dense(output_shape, kernel_initializer= he_uniform(),
                       bias_initializer= "zeros", 
                       kernel_regularizer= l2(l= kernel_regularizer),
                       bias_regularizer= l2(l= bias_regularizer))(lstm)
        x= BatchNormalization()(dense_1)
        x= relu(x)
        x= Dropout(rate= dropout_rate)(x)
        o= Dense(output_shape, kernel_initializer= glorot_uniform(),
                 bias_initializer= "zeros", 
                 kernel_regularizer= l2(l= kernel_regularizer), 
                 bias_regularizer= l2(l= bias_regularizer))(dense_1)
        o= BatchNormalization()(o)
        output= softmax(o, axis= 1)
        
        loss= CC()
        metrics= AUC()
        optimizer= Adam()
        self.model= Model(inputs= [input_layer], outputs= [output])
        self.model.compile(optimizer= optimizer, loss= loss, metrics= [metrics])
        
        
    def train(self, x, y, validation_split, epochs):
        self.model.fit(x, y, validation_split= validation_split, epochs= epochs)
        
    def predict(self, x):
        return self.model.predict(x)

# %%
steps= xtr_transformed.shape[1]
dim= xtr_transformed.shape[2]
output_shape= ytr_encoded.shape[1]

model= LSTMModel()
model.build_model(input_dim= dim,
                  output_shape= output_shape,
                  steps= steps, 
                  dropout_rate= 0.5, 
                  bias_regularizer= 0.3, 
                  kernel_regularizer= 0.3)

# %%
model.train(xtr_transformed, ytr_encoded,
           0.2, 120)
# Out:
# Epoch 1/120
# 9/9 [==============================] - 4s 163ms/step - loss: 10.7217 - auc: 0.8232 - val_loss: 10.7457 - val_auc: 0.9230
# Epoch 2/120
# 9/9 [==============================] - 1s 74ms/step - loss: 9.8271 - auc: 0.9765 - val_loss: 10.3168 - val_auc: 0.9371
# Epoch 3/120
# 9/9 [==============================] - 1s 73ms/step - loss: 9.2613 - auc: 0.9916 - val_loss: 9.9069 - val_auc: 0.9465
# Epoch 4/120
# 9/9 [==============================] - 1s 92ms/step - loss: 8.7844 - auc: 0.9949 - val_loss: 9.5179 - val_auc: 0.9444
# Epoch 5/120
# 9/9 [==============================] - 1s 88ms/step - loss: 8.3417 - auc: 0.9980 - val_loss: 9.1408 - val_auc: 0.9436
# Epoch 6/120
# 9/9 [==============================] - 1s 78ms/step - loss: 7.9329 - auc: 0.9990 - val_loss: 8.7838 - val_auc: 0.9444
# Epoch 7/120
# 9/9 [==============================] - 1s 88ms/step - loss: 7.5636 - auc: 0.9997 - val_loss: 8.4451 - val_auc: 0.9280
# Epoch 8/120
# 9/9 [==============================] - 1s 91ms/step - loss: 7.1880 - auc: 0.9999 - val_loss: 8.1161 - val_auc: 0.8967
# Epoch 9/120
# 9/9 [==============================] - 1s 78ms/step - loss: 6.8511 - auc: 1.0000 - val_loss: 7.7972 - val_auc: 0.8840
# Epoch 10/120
# 9/9 [==============================] - 1s 82ms/step - loss: 6.5221 - auc: 1.0000 - val_loss: 7.4745 - val_auc: 0.9357
# Epoch 11/120
# 9/9 [==============================] - 1s 79ms/step - loss: 6.2238 - auc: 0.9999 - val_loss: 7.1620 - val_auc: 0.9481
# Epoch 12/120
# 9/9 [==============================] - 1s 94ms/step - loss: 5.9182 - auc: 0.9999 - val_loss: 6.8458 - val_auc: 0.9505
# Epoch 13/120
# 9/9 [==============================] - 1s 94ms/step - loss: 5.6518 - auc: 1.0000 - val_loss: 6.5443 - val_auc: 0.9514
# Epoch 14/120
# 9/9 [==============================] - 1s 85ms/step - loss: 5.3773 - auc: 1.0000 - val_loss: 6.2504 - val_auc: 0.9542
# Epoch 15/120
# 9/9 [==============================] - 1s 79ms/step - loss: 5.1676 - auc: 1.0000 - val_loss: 5.9741 - val_auc: 0.9563
# Epoch 16/120
# 9/9 [==============================] - 1s 73ms/step - loss: 4.9248 - auc: 1.0000 - val_loss: 5.7293 - val_auc: 0.9572
# Epoch 17/120
# 9/9 [==============================] - 1s 78ms/step - loss: 4.6791 - auc: 1.0000 - val_loss: 5.4855 - val_auc: 0.9612
# Epoch 18/120
# 9/9 [==============================] - 1s 86ms/step - loss: 4.4796 - auc: 1.0000 - val_loss: 5.2453 - val_auc: 0.9618
# Epoch 19/120
# 9/9 [==============================] - 1s 85ms/step - loss: 4.2626 - auc: 1.0000 - val_loss: 5.0177 - val_auc: 0.9647
# Epoch 20/120
# 9/9 [==============================] - 1s 86ms/step - loss: 4.0851 - auc: 1.0000 - val_loss: 4.8176 - val_auc: 0.9645
# Epoch 21/120
# 9/9 [==============================] - 1s 73ms/step - loss: 3.8861 - auc: 1.0000 - val_loss: 4.6381 - val_auc: 0.9670
# Epoch 22/120
# 9/9 [==============================] - 1s 77ms/step - loss: 3.7095 - auc: 1.0000 - val_loss: 4.4363 - val_auc: 0.9709
# Epoch 23/120
# 9/9 [==============================] - 1s 70ms/step - loss: 3.5396 - auc: 1.0000 - val_loss: 4.2356 - val_auc: 0.9704
# Epoch 24/120
# 9/9 [==============================] - 1s 86ms/step - loss: 3.3926 - auc: 1.0000 - val_loss: 4.0792 - val_auc: 0.9706
# Epoch 25/120
# 9/9 [==============================] - 1s 81ms/step - loss: 3.2359 - auc: 1.0000 - val_loss: 3.8907 - val_auc: 0.9738
# Epoch 26/120
# 9/9 [==============================] - 1s 86ms/step - loss: 3.0835 - auc: 1.0000 - val_loss: 3.7595 - val_auc: 0.9744
# Epoch 27/120
# 9/9 [==============================] - 1s 81ms/step - loss: 2.9354 - auc: 1.0000 - val_loss: 3.5917 - val_auc: 0.9761
# Epoch 28/120
# 9/9 [==============================] - 1s 71ms/step - loss: 2.8227 - auc: 1.0000 - val_loss: 3.4402 - val_auc: 0.9753
# Epoch 29/120
# 9/9 [==============================] - 1s 77ms/step - loss: 2.6724 - auc: 1.0000 - val_loss: 3.3026 - val_auc: 0.9787
# Epoch 30/120
# 9/9 [==============================] - 1s 80ms/step - loss: 2.5741 - auc: 1.0000 - val_loss: 3.1810 - val_auc: 0.9764
# Epoch 31/120
# 9/9 [==============================] - 1s 86ms/step - loss: 2.4505 - auc: 1.0000 - val_loss: 3.0446 - val_auc: 0.9800
# Epoch 32/120
# 9/9 [==============================] - 1s 81ms/step - loss: 2.3406 - auc: 1.0000 - val_loss: 2.9295 - val_auc: 0.9785
# Epoch 33/120
# 9/9 [==============================] - 1s 97ms/step - loss: 2.2310 - auc: 1.0000 - val_loss: 2.8126 - val_auc: 0.9799
# Epoch 34/120
# 9/9 [==============================] - 1s 91ms/step - loss: 2.1274 - auc: 1.0000 - val_loss: 2.7100 - val_auc: 0.9802
# Epoch 35/120
# 9/9 [==============================] - 1s 74ms/step - loss: 2.0364 - auc: 1.0000 - val_loss: 2.5989 - val_auc: 0.9824
# Epoch 36/120
# 9/9 [==============================] - 1s 77ms/step - loss: 1.9400 - auc: 1.0000 - val_loss: 2.5056 - val_auc: 0.9845
# Epoch 37/120
# 9/9 [==============================] - 1s 97ms/step - loss: 1.8617 - auc: 1.0000 - val_loss: 2.4186 - val_auc: 0.9837
# Epoch 38/120
# 9/9 [==============================] - 1s 66ms/step - loss: 1.8028 - auc: 1.0000 - val_loss: 2.3269 - val_auc: 0.9843
# Epoch 39/120
# 9/9 [==============================] - 1s 78ms/step - loss: 1.7200 - auc: 1.0000 - val_loss: 2.2432 - val_auc: 0.9821
# Epoch 40/120
# 9/9 [==============================] - 1s 85ms/step - loss: 1.6465 - auc: 1.0000 - val_loss: 2.1803 - val_auc: 0.9822
# Epoch 41/120
# 9/9 [==============================] - 1s 88ms/step - loss: 1.5751 - auc: 1.0000 - val_loss: 2.0875 - val_auc: 0.9832
# Epoch 42/120
# 9/9 [==============================] - 1s 91ms/step - loss: 1.5102 - auc: 1.0000 - val_loss: 2.0245 - val_auc: 0.9832
# Epoch 43/120
# 9/9 [==============================] - 1s 86ms/step - loss: 1.4511 - auc: 1.0000 - val_loss: 1.9686 - val_auc: 0.9827
# Epoch 44/120
# 9/9 [==============================] - 1s 75ms/step - loss: 1.4179 - auc: 0.9999 - val_loss: 1.8923 - val_auc: 0.9815
# Epoch 45/120
# 9/9 [==============================] - 1s 88ms/step - loss: 1.3162 - auc: 1.0000 - val_loss: 1.8361 - val_auc: 0.9825
# Epoch 46/120
# 9/9 [==============================] - 1s 86ms/step - loss: 1.2652 - auc: 1.0000 - val_loss: 1.7790 - val_auc: 0.9808
# Epoch 47/120
# 9/9 [==============================] - 1s 85ms/step - loss: 1.2386 - auc: 1.0000 - val_loss: 1.7148 - val_auc: 0.9815
# Epoch 48/120
# 9/9 [==============================] - 1s 84ms/step - loss: 1.1857 - auc: 1.0000 - val_loss: 1.6691 - val_auc: 0.9806
# Epoch 49/120
# 9/9 [==============================] - 1s 81ms/step - loss: 1.1479 - auc: 1.0000 - val_loss: 1.6119 - val_auc: 0.9813
# Epoch 50/120
# 9/9 [==============================] - 1s 92ms/step - loss: 1.1017 - auc: 1.0000 - val_loss: 1.5625 - val_auc: 0.9805
# Epoch 51/120
# 9/9 [==============================] - 1s 92ms/step - loss: 1.0456 - auc: 1.0000 - val_loss: 1.5240 - val_auc: 0.9790
# Epoch 52/120
# 9/9 [==============================] - 1s 75ms/step - loss: 1.0164 - auc: 1.0000 - val_loss: 1.4667 - val_auc: 0.9826
# Epoch 53/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.9887 - auc: 1.0000 - val_loss: 1.4398 - val_auc: 0.9816
# Epoch 54/120
# 9/9 [==============================] - 1s 95ms/step - loss: 0.9514 - auc: 1.0000 - val_loss: 1.3825 - val_auc: 0.9838
# Epoch 55/120
# 9/9 [==============================] - 1s 84ms/step - loss: 0.9385 - auc: 1.0000 - val_loss: 1.3565 - val_auc: 0.9798
# Epoch 56/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.8791 - auc: 1.0000 - val_loss: 1.3080 - val_auc: 0.9828
# Epoch 57/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.8633 - auc: 1.0000 - val_loss: 1.2730 - val_auc: 0.9836
# Epoch 58/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.8343 - auc: 1.0000 - val_loss: 1.2349 - val_auc: 0.9825
# Epoch 59/120
# 9/9 [==============================] - 1s 78ms/step - loss: 0.8035 - auc: 1.0000 - val_loss: 1.2022 - val_auc: 0.9843
# Epoch 60/120
# 9/9 [==============================] - 1s 88ms/step - loss: 0.7995 - auc: 1.0000 - val_loss: 1.1633 - val_auc: 0.9852
# Epoch 61/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.7780 - auc: 1.0000 - val_loss: 1.1339 - val_auc: 0.9856
# Epoch 62/120
# 9/9 [==============================] - 1s 88ms/step - loss: 0.7497 - auc: 1.0000 - val_loss: 1.1146 - val_auc: 0.9845
# Epoch 63/120
# 9/9 [==============================] - 1s 83ms/step - loss: 0.7120 - auc: 1.0000 - val_loss: 1.0774 - val_auc: 0.9860
# Epoch 64/120
# 9/9 [==============================] - 1s 79ms/step - loss: 0.7083 - auc: 1.0000 - val_loss: 1.0535 - val_auc: 0.9850
# Epoch 65/120
# 9/9 [==============================] - 1s 91ms/step - loss: 0.6781 - auc: 1.0000 - val_loss: 1.0209 - val_auc: 0.9858
# Epoch 66/120
# 9/9 [==============================] - 1s 93ms/step - loss: 0.6575 - auc: 1.0000 - val_loss: 1.0045 - val_auc: 0.9850
# Epoch 67/120
# 9/9 [==============================] - 1s 89ms/step - loss: 0.6475 - auc: 1.0000 - val_loss: 0.9716 - val_auc: 0.9872
# Epoch 68/120
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6472 - auc: 1.0000 - val_loss: 0.9647 - val_auc: 0.9868
# Epoch 69/120
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6277 - auc: 1.0000 - val_loss: 0.9305 - val_auc: 0.9877
# Epoch 70/120
# 9/9 [==============================] - 1s 93ms/step - loss: 0.6138 - auc: 1.0000 - val_loss: 0.9263 - val_auc: 0.9867
# Epoch 71/120
# 9/9 [==============================] - 1s 78ms/step - loss: 0.6068 - auc: 1.0000 - val_loss: 0.8984 - val_auc: 0.9886
# Epoch 72/120
# 9/9 [==============================] - 1s 89ms/step - loss: 0.6038 - auc: 1.0000 - val_loss: 0.8752 - val_auc: 0.9863
# Epoch 73/120
# 9/9 [==============================] - 1s 86ms/step - loss: 0.5731 - auc: 1.0000 - val_loss: 0.8741 - val_auc: 0.9835
# Epoch 74/120
# 9/9 [==============================] - 1s 80ms/step - loss: 0.5836 - auc: 1.0000 - val_loss: 0.8505 - val_auc: 0.9858
# Epoch 75/120
# 9/9 [==============================] - 1s 97ms/step - loss: 0.5678 - auc: 1.0000 - val_loss: 0.8269 - val_auc: 0.9884
# Epoch 76/120
# 9/9 [==============================] - 1s 88ms/step - loss: 0.5422 - auc: 1.0000 - val_loss: 0.8211 - val_auc: 0.9874
# Epoch 77/120
# 9/9 [==============================] - 1s 92ms/step - loss: 0.5267 - auc: 1.0000 - val_loss: 0.8049 - val_auc: 0.9857
# Epoch 78/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.5378 - auc: 1.0000 - val_loss: 0.7980 - val_auc: 0.9868
# Epoch 79/120
# 9/9 [==============================] - 1s 83ms/step - loss: 0.5075 - auc: 1.0000 - val_loss: 0.7808 - val_auc: 0.9850
# Epoch 80/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.5079 - auc: 1.0000 - val_loss: 0.7740 - val_auc: 0.9817
# Epoch 81/120
# 9/9 [==============================] - 1s 88ms/step - loss: 0.5176 - auc: 1.0000 - val_loss: 0.7664 - val_auc: 0.9842
# Epoch 82/120
# 9/9 [==============================] - 1s 83ms/step - loss: 0.5156 - auc: 1.0000 - val_loss: 0.7525 - val_auc: 0.9840
# Epoch 83/120
# 9/9 [==============================] - 1s 83ms/step - loss: 0.4990 - auc: 1.0000 - val_loss: 0.7451 - val_auc: 0.9835
# Epoch 84/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4988 - auc: 1.0000 - val_loss: 0.7438 - val_auc: 0.9842
# Epoch 85/120
# 9/9 [==============================] - 1s 86ms/step - loss: 0.4711 - auc: 1.0000 - val_loss: 0.7328 - val_auc: 0.9890
# Epoch 86/120
# 9/9 [==============================] - 1s 93ms/step - loss: 0.4786 - auc: 1.0000 - val_loss: 0.7224 - val_auc: 0.9808
# Epoch 87/120
# 9/9 [==============================] - 1s 95ms/step - loss: 0.4716 - auc: 1.0000 - val_loss: 0.7384 - val_auc: 0.9896
# Epoch 88/120
# 9/9 [==============================] - 1s 96ms/step - loss: 0.4658 - auc: 1.0000 - val_loss: 0.7130 - val_auc: 0.9792
# Epoch 89/120
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4596 - auc: 1.0000 - val_loss: 0.7251 - val_auc: 0.9819
# Epoch 90/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4690 - auc: 1.0000 - val_loss: 0.6759 - val_auc: 0.9805
# Epoch 91/120
# 9/9 [==============================] - 1s 86ms/step - loss: 0.4465 - auc: 1.0000 - val_loss: 0.6806 - val_auc: 0.9695
# Epoch 92/120
# 9/9 [==============================] - 1s 91ms/step - loss: 0.4462 - auc: 1.0000 - val_loss: 0.6667 - val_auc: 0.9808
# Epoch 93/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4441 - auc: 1.0000 - val_loss: 0.6703 - val_auc: 0.9807
# Epoch 94/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4364 - auc: 1.0000 - val_loss: 0.6686 - val_auc: 0.9807
# Epoch 95/120
# 9/9 [==============================] - 1s 96ms/step - loss: 0.4544 - auc: 1.0000 - val_loss: 0.6645 - val_auc: 0.9793
# Epoch 96/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.4168 - auc: 1.0000 - val_loss: 0.6595 - val_auc: 0.9800
# Epoch 97/120
# 9/9 [==============================] - 1s 93ms/step - loss: 0.4233 - auc: 1.0000 - val_loss: 0.6524 - val_auc: 0.9803
# Epoch 98/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.4152 - auc: 1.0000 - val_loss: 0.6455 - val_auc: 0.9800
# Epoch 99/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4043 - auc: 1.0000 - val_loss: 0.6501 - val_auc: 0.9802
# Epoch 100/120
# 9/9 [==============================] - 1s 88ms/step - loss: 0.4121 - auc: 1.0000 - val_loss: 0.6512 - val_auc: 0.9732
# Epoch 101/120
# 9/9 [==============================] - 1s 85ms/step - loss: 0.4121 - auc: 1.0000 - val_loss: 0.6388 - val_auc: 0.9736
# Epoch 102/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.4066 - auc: 1.0000 - val_loss: 0.6460 - val_auc: 0.9822
# Epoch 103/120
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3894 - auc: 1.0000 - val_loss: 0.6527 - val_auc: 0.9744
# Epoch 104/120
# 9/9 [==============================] - 1s 90ms/step - loss: 0.3938 - auc: 1.0000 - val_loss: 0.6472 - val_auc: 0.9749
# Epoch 105/120
# 9/9 [==============================] - 1s 97ms/step - loss: 0.3895 - auc: 1.0000 - val_loss: 0.6446 - val_auc: 0.9757
# Epoch 106/120
# 9/9 [==============================] - 1s 98ms/step - loss: 0.4068 - auc: 1.0000 - val_loss: 0.6276 - val_auc: 0.9786
# Epoch 107/120
# 9/9 [==============================] - 1s 91ms/step - loss: 0.3974 - auc: 1.0000 - val_loss: 0.6329 - val_auc: 0.9791
# Epoch 108/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3898 - auc: 1.0000 - val_loss: 0.6348 - val_auc: 0.9815
# Epoch 109/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3765 - auc: 1.0000 - val_loss: 0.6303 - val_auc: 0.9801
# Epoch 110/120
# 9/9 [==============================] - 1s 81ms/step - loss: 0.3849 - auc: 1.0000 - val_loss: 0.6325 - val_auc: 0.9797
# Epoch 111/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3758 - auc: 1.0000 - val_loss: 0.6280 - val_auc: 0.9799
# Epoch 112/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3778 - auc: 1.0000 - val_loss: 0.6221 - val_auc: 0.9803
# Epoch 113/120
# 9/9 [==============================] - 1s 89ms/step - loss: 0.3724 - auc: 1.0000 - val_loss: 0.6222 - val_auc: 0.9791
# Epoch 114/120
# 9/9 [==============================] - 1s 94ms/step - loss: 0.3791 - auc: 1.0000 - val_loss: 0.6194 - val_auc: 0.9805
# Epoch 115/120
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3677 - auc: 1.0000 - val_loss: 0.6093 - val_auc: 0.9804
# Epoch 116/120
# 9/9 [==============================] - 1s 93ms/step - loss: 0.3821 - auc: 1.0000 - val_loss: 0.6070 - val_auc: 0.9797
# Epoch 117/120
# 9/9 [==============================] - 1s 96ms/step - loss: 0.3594 - auc: 1.0000 - val_loss: 0.6059 - val_auc: 0.9780
# Epoch 118/120
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3569 - auc: 1.0000 - val_loss: 0.6015 - val_auc: 0.9781
# Epoch 119/120
# 9/9 [==============================] - 1s 92ms/step - loss: 0.3619 - auc: 1.0000 - val_loss: 0.6014 - val_auc: 0.9809
# Epoch 120/120
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3563 - auc: 1.0000 - val_loss: 0.5980 - val_auc: 0.9790

# %%
from sklearn.metrics import classification_report

prediction= y_encoder.inverse_transform(model.predict(xtr_transformed))
#print(classification_report(train_data.tag, prediction))
# Out:
# 11/11 [==============================] - 1s 31ms/step

# %%
prediction
# Out:
# array([['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['salary slip'],
#        ['employment proof'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['address proof'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['address proof'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['employment proof'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['address proof'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['employment proof'],
#        ['salary slip'],
#        ['bank statement'],
#        ['salary slip'],
#        ['receipt'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['invoice'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['tax return'],
#        ['invoice'],
#        ['receipt'],
#        ['tax return'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['employment proof'],
#        ['salary slip'],
#        ['invoice'],
#        ['bank statement'],
#        ['business proof'],
#        ['invoice'],
#        ['address proof'],
#        ['bank statement'],
#        ['receipt'],
#        ['fund raising'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['tax return'],
#        ['business proof'],
#        ['invoice'],
#        ['invoice'],
#        ['invoice'],
#        ['address proof'],
#        ['bank statement'],
#        ['invoice'],
#        ['tax return'],
#        ['receipt'],
#        ['employment proof'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['employment proof'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['address proof'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['tax return'],
#        ['business proof'],
#        ['bank statement'],
#        ['address proof'],
#        ['business proof'],
#        ['receipt'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['salary slip'],
#        ['invoice'],
#        ['address proof'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['salary slip'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['salary slip'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['receipt'],
#        ['salary slip'],
#        ['salary slip'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['fund raising'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['tax return'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['salary slip'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['salary slip'],
#        ['salary slip'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['salary slip'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['invoice'],
#        ['invoice'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['receipt'],
#        ['receipt'],
#        ['salary slip'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['bank statement'],
#        ['receipt'],
#        ['salary slip'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['salary slip'],
#        ['receipt'],
#        ['bank statement'],
#        ['invoice'],
#        ['receipt'],
#        ['bank statement'],
#        ['bank statement'],
#        ['invoice'],
#        ['bank statement'],
#        ['invoice'],
#        ['salary slip'],
#        ['bank statement']], dtype=object)

# %%
from PIL import Image
from pytesseract import pytesseract
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.luhn import LuhnSummarizer
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
import pandas as pd
import numpy as np

def receipt1(image_path):
    path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#image_path = r"bank1.png"
    #image_path="C:\Users\SJain\Documents\samples\bank statements\"
# Opening the image & storing it in an image object
    img = Image.open(image_path)

# Providing the tesseract executable
# location to pytesseract library
    pytesseract.tesseract_cmd = path_to_tesseract

# Passing the image object to image_to_string() function
# This function will extract the text from the image
    text = pytesseract.image_to_string(img)
    text=text.replace("\n\n"," ").replace("[","").replace("-","").replace(".—","").replace("|","").replace(":","")
    text=text.replace("|","").replace("§","").replace("@","").replace("¥","").replace("©","")
    text=text.replace("«","")
    text=text.replace("\n"," ")
    text=text.replace(">","")
# Displaying the extracted text
    #print(text[:-1])
    
    l=[]
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    #print(tokens_without_sw)
    l.append(tokens_without_sw)
    l2=[]
    for i in l:
        r=TreebankWordDetokenizer().detokenize(i)
        l2.append(r)
    lst=[]
    ps = PorterStemmer()
    for i in l2:
    #text_tokens = word_tokenize(i)
    #tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
        res=ps.stem(i)
   # res=res.replace(" | "," ")
    #res = i.translate(remove_digits)
        lst.append(res)
    df1 = {
     'Text' :lst
    }
 
    df1 = pd.DataFrame(df1,columns=['Text'])
    #print(df1)
    return df1
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SJain\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
re1=receipt1("receipt_99.png")

# %%
test = re1['Text']
test
# Out:
# 0    the aiml store 1234 somewhere . rd poway, cali...
# Name: Text, dtype: object

# %%
re1.to_csv("testsample.csv")

# %%
def build1():
    #text=['NSF Checks','Supply Inventory','PayPal Bank','Fixed Assets','Proshop Inventory','TD-operations 9798','Emp W/H-Medical','Rent - 55+ Housing']
    #text=['Emp W/H-Medical','Rent - 55+ Housing']
    #text1=['Laptop']
    text=['the aiml store 1234 somewhere . rd poway, california 92129 02/13/2022 1228 am tances eea belkin soreenforce tempered; oy $35.00 blas screen oc . 4 hogwarts wooden steamer trek 1 sar; sbt sed . t = ca tax 7 . 7800 161 75 1; total 8161 . 745 002 visa char s161 . 76 oe aid ag000407307 162 visa debit oauth code 07162 some promotions may . reduce the "refund valle of items appic peacoat aindiinchpancbacdat pobsece we feedback! take quick survey enter chance â€œ to hin $260 store gift card . go â€™ "myfakestore . com/win â€œ winners monthiy * (rce darori rocco aoi ata ioick cashier jot doe store 123 pos 003 transact ion 2629 sunday, february 12, 2022 1228 am']
    data = [name.lower() for name in text]
    tokenized_test=tokenizer.texts_to_sequences(data)
    test_padded= pad_sequences(tokenized_test, maxlen= 20, padding= "pre")
    xts_transformed=transform_x(test_padded,tokenizer)
    prediction_test1= y_encoder.inverse_transform(model.predict(xts_transformed))
    
   # prediction_test2= y_encoder.inverse_transform(model.predict_(xts_transformed))
    print(prediction_test1)
    #print(prediction_test2)

# %%
build1()
# Out:
# 1/1 [==============================] - 0s 26ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 build1()
#
# Cell In [34], line 12, in build1()
#       9 xts_transformed=transform_x(test_padded,tokenizer)
#      10 prediction_test1= y_encoder.inverse_transform(model.predict(xts_transformed))
# ---> 12 prediction_test2= y_encoder.inverse_transform(model.predict_proba(xts_transformed))
#      13 print(prediction_test1)
#      14 print(prediction_test2)
#
# AttributeError: 'LSTMModel' object has no attribute 'predict_proba'

# %%
print(classification_report(train_data.Tag, prediction))
# Out:
#                   precision    recall  f1-score   support
#
#    address proof       1.00      0.80      0.89        10
#   bank statement       0.99      0.98      0.99       105
#   business proof       1.00      0.80      0.89         5
# employment proof       1.00      0.86      0.92         7
#     fund raising       1.00      1.00      1.00         2
#          invoice       1.00      1.00      1.00        98
#          receipt       1.00      1.00      1.00       102
#      salary slip       0.59      1.00      0.74        10
#       tax return       1.00      0.75      0.86         8
#
#         accuracy                           0.98       347
#        macro avg       0.95      0.91      0.92       347
#     weighted avg       0.99      0.98      0.98       347
